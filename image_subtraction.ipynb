# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import errno
import os
import sys

from skimage import io

#from im_reduction import *

# %%
# import image, background 
path_to_images= '/home/sara/Documents/SECAR/Diagnostics/Viewer-Image-Analysis/images/stability_FP2/cropped/'  
#bg= io.imread(path_to_images+'/D1568_8_28_19_overnight_stability_056_BG.tiff')        

#raw_image = io.imread(path_to_images+'/D1568_8_28_19_overnight_stability_043.tiff')

# %%
files = [f for f in sorted(os.listdir(path_to_images))]

# %%
sub_images = {}


for i, file in enumerate(files):
    
    cur_im =  io.imread(path_to_images + files[i+1])
    prec_im =  io.imread(path_to_images + files[i])
   
    sub_im = cur_im.astype(int) - prec_im.astype(int)
    
    sub_images[i+1] = sub_im
    
    plt.imshow(sub_im)
    #plt.savefig(f"viewer_stability_subtracted{i}.jpg", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-888455deebf1> in <module>()
#       4 for i, file in enumerate(files):
#       5
# ----> 6     cur_im =  io.imread(path_to_images + files[i+1])
#       7     prec_im =  io.imread(path_to_images + files[i])
#       8
#
# IndexError: list index out of range

# %%
plt.figure(figsize=(30,30))


k=0

for i in range(25):
    for j in range(25):
        plt.subplot2grid((25, 25), (i,j))
        plt.imshow(sub_images[image])

        k = k + 1
#plt.tight_layout()
plt.savefig("viewer_stability_subtracted.jpg", dpi=300)
plt.show()
